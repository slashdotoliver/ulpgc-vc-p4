# %% [markdown]
# #Paquetes necesarios

# %%
import cv2  
import math 

from ultralytics import YOLO

# %% [markdown]
# Modelos preentrenados, visualizando con las utilidades de ultralytics

# %%
# Carga del modelo
#model = YOLO('yolo11n.pt') #Contenedores
#model = YOLO('yolo11n-seg.pt') #Máscaras
model = YOLO('yolo11n-pose.pt')  #Pose

#Para un vídeo 
filename = "TGC23_PdH_C0056cut.mp4"
results = model(filename, show=True)

cv2.destroyAllWindows()
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
# The DISPLAY environment variable isn't set.
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 127.5ms
# video 1/1 (frame 2/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 112.7ms
# video 1/1 (frame 3/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.3ms
# video 1/1 (frame 4/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 94.4ms
# video 1/1 (frame 5/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.0ms
# video 1/1 (frame 6/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 88.3ms
# video 1/1 (frame 7/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 96.5ms
# video 1/1 (frame 8/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 109.4ms
# video 1/1 (frame 9/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 90.9ms
# video 1/1 (frame 10/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.3ms
# video 1/1 (frame 11/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 90.9ms
# video 1/1 (frame 12/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 186.7ms
# video 1/1 (frame 13/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 125.3ms
# video 1/1 (frame 14/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 91.3ms
# video 1/1 (frame 15/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 95.0ms
# video 1/1 (frame 16/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 93.4ms
# video 1/1 (frame 17/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.0ms
# video 1/1 (frame 18/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.3ms
# video 1/1 (frame 19/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 204.0ms
# video 1/1 (frame 20/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 94.5ms
# video 1/1 (frame 21/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 96.6ms
# video 1/1 (frame 22/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.2ms
# video 1/1 (frame 23/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 96.5ms
# video 1/1 (frame 24/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 90.8ms
# video 1/1 (frame 25/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.9ms
# video 1/1 (frame 26/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 160.4ms
# video 1/1 (frame 27/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 150.2ms
# video 1/1 (frame 28/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 89.8ms
# video 1/1 (frame 29/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 95.5ms
# video 1/1 (frame 30/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.5ms
# video 1/1 (frame 31/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.4ms
# video 1/1 (frame 32/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 159.1ms
# video 1/1 (frame 33/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 141.3ms
# video 1/1 (frame 34/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.0ms
# video 1/1 (frame 35/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 92.8ms
# video 1/1 (frame 36/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 95.5ms
# video 1/1 (frame 37/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.6ms
# video 1/1 (frame 38/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 98.1ms
# video 1/1 (frame 39/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 99.0ms
# video 1/1 (frame 40/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 92.4ms
# video 1/1 (frame 41/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 91.9ms
# video 1/1 (frame 42/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.6ms
# video 1/1 (frame 43/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.0ms
# video 1/1 (frame 44/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 127.8ms
# video 1/1 (frame 45/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.8ms
# video 1/1 (frame 46/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 100.1ms
# video 1/1 (frame 47/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 95.4ms
# video 1/1 (frame 48/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 106.2ms
# video 1/1 (frame 49/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 94.3ms
# video 1/1 (frame 50/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 102.0ms
# video 1/1 (frame 51/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 115.6ms
# video 1/1 (frame 52/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.9ms
# video 1/1 (frame 53/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 115.8ms
# video 1/1 (frame 54/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 107.3ms
# video 1/1 (frame 55/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 111.2ms
# video 1/1 (frame 56/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 103.4ms
# video 1/1 (frame 57/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 105.0ms
# video 1/1 (frame 58/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 104.6ms
# video 1/1 (frame 59/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 101.1ms
# video 1/1 (frame 60/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 126.3ms
# video 1/1 (frame 61/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 108.6ms
# video 1/1 (frame 62/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections),
375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 93.7ms
# video 1/1 (frame 366/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 94.2ms
# video 1/1 (frame 367/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 92.8ms
# video 1/1 (frame 368/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 95.4ms
# video 1/1 (frame 369/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 91.7ms
# video 1/1 (frame 370/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 94.3ms
# video 1/1 (frame 371/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 96.6ms
# video 1/1 (frame 372/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 90.8ms
# video 1/1 (frame 373/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 95.2ms
# video 1/1 (frame 374/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 92.4ms
# video 1/1 (frame 375/375) /shared/VC/ulpgc-vc-p4/TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 97.6ms
# Speed: 1.8ms preprocess, 102.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# Desde cámara, detección con yolo11, modelo nano. Visualización propia con OpenCV

# %%
# Carga del modelo, descarga en disco si no está presente en la carpeta
model = YOLO('yolo11n.pt') #Contenedores

# Etiqueta de las distintas clases
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


# Captura desde la webcam
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Detecta en la imagen
        results = model(img, stream=True)
        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confianza --->",confidence)

                # Clase
                cls = int(box.cls[0])
                print("Clase -->", classNames[cls])

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 11.6MB/s 0.5s.4s<0.1s.8s
#
# 0: 480x640 (no detections), 101.4ms
# Speed: 15.4ms preprocess, 101.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# 0: 480x640 (no detections), 173.1ms
# Speed: 29.1ms preprocess, 173.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.2ms
# Speed: 8.9ms preprocess, 75.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 109.9ms
# Speed: 1.2ms preprocess, 109.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 108.4ms
# Speed: 12.7ms preprocess, 108.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 111.4ms
# Speed: 1.4ms preprocess, 111.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 81.6ms
# Speed: 3.3ms preprocess, 81.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.2ms
# Speed: 5.9ms preprocess, 60.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.1ms
# Speed: 1.1ms preprocess, 56.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 1.0ms preprocess, 59.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.4ms
# Speed: 0.9ms preprocess, 57.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 62.9ms
# Speed: 1.1ms preprocess, 62.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.9ms
# Speed: 5.7ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.5ms
# Speed: 3.8ms preprocess, 56.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.4ms
# Speed: 1.2ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.0ms
# Speed: 1.6ms preprocess, 53.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 55.8ms
# Speed: 1.1ms preprocess, 55.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.6ms
# Confianza ---> 0.39
# Clase --> person
# Speed: 1.0ms preprocess, 53.6ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.6ms
# Speed: 1.1ms preprocess, 54.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.6ms
# Speed: 2.5ms preprocess, 58.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.9ms
# Speed: 1.2ms preprocess, 57.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 78.5ms
# Speed: 4.5ms preprocess, 78.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 146.7ms
# Speed: 1.2ms preprocess, 146.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.3ms
# Speed: 1.1ms preprocess, 58.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.9ms
# Speed: 1.1ms preprocess, 51.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.3ms
# Speed: 1.9ms preprocess, 58.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 50.3ms
# Speed: 1.2ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.8ms
# Speed: 1.1ms preprocess, 61.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.8ms
# Speed: 3.3ms preprocess, 54.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.8ms
# Speed: 1.7ms preprocess, 52.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.4ms
# Confianza ---> 0.33
# Clase --> person
# Speed: 1.8ms preprocess, 50.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.2ms
# Speed: 1.0ms preprocess, 56.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 kites, 57.6ms
# Confianza ---> 0.63
# Clase --> person
# Confianza ---> 0.49
# Clase --> kite
# Confianza ---> 0.36
# Clase --> kite
# Confianza ---> 0.28
# Clase --> kite
# Confianza ---> 0.26
# Clase --> kite
# Speed: 1.1ms preprocess, 57.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 5 kites, 50.5ms
# Confianza ---> 0.6
# Clase --> kite
# Confianza ---> 0.55
# Clase --> kite
# Confianza ---> 0.51
# Clase --> person
# Confianza ---> 0.41
# Clase --> kite
# Confianza ---> 0.4
# Clase --> kite
# Confianza ---> 0.36
# Clase --> kite
# Speed: 1.2ms preprocess, 50.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.1ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.1ms preprocess, 56.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.3ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 1.4ms preprocess, 53.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.1ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.2ms preprocess, 54.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.5ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 1.1ms preprocess, 56.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.3ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 1.1ms preprocess, 53.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.9ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 1.2ms preprocess, 57.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.9ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.2ms preprocess, 56.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 62.3ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 6.9ms preprocess, 62.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.1ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.3ms preprocess, 51.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.1ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 1.1ms preprocess, 53.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.7ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 1.2ms preprocess, 60.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.7ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.1ms preprocess, 56.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.3ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.0ms preprocess, 57.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.1ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.0ms preprocess, 55.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.2ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.1ms preprocess, 63.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.4ms preprocess, 59.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.3ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.5ms preprocess, 52.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.2ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 2.1ms preprocess, 58.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.8ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.9ms preprocess, 51.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 11.0ms preprocess, 60.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 65.4ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.4ms preprocess, 65.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.7ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.1ms preprocess, 60.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.4ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.0ms preprocess, 51.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.8ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.0ms preprocess, 53.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.3ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.0ms preprocess, 53.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.0ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.2ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.2ms preprocess, 51.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.3ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.1ms preprocess, 55.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.9ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.1ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 72.9ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 5.8ms preprocess, 72.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 156.1ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 15.8ms preprocess, 156.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.9ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.0ms preprocess, 56.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.9ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 0.9ms preprocess, 57.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.6ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.8ms preprocess, 54.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.5ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.49
# Clase --> person
# Speed: 1.3ms preprocess, 56.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Confianza ---> 0.92
# Clase --> person
# Speed: 1.0ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.0ms
# Confianza ---> 0.92
# Clase --> person
# Speed: 1.4ms preprocess, 57.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Confianza ---> 0.92
# Clase --> person
# Speed: 1.2ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.5ms
# Confianza ---> 0.92
# Clase --> person
# Speed: 1.1ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.7ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.6ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 58.4ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.35
# Clase --> person
# Speed: 6.8ms preprocess, 58.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 56.3ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.34
# Clase --> person
# Speed: 1.0ms preprocess, 56.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 54.4ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.37
# Clase --> person
# Speed: 1.4ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.5ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 1.2ms preprocess, 55.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.0ms preprocess, 64.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.2ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.0ms preprocess, 56.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.0ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.3ms preprocess, 57.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.6ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.6ms preprocess, 56.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 58.0ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.1ms preprocess, 58.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 148.3ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 14.7ms preprocess, 148.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 68.1ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.32
# Clase --> person
# Speed: 1.0ms preprocess, 68.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 59.3ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.5
# Clase --> person
# Confianza ---> 0.29
# Clase --> person
# Speed: 1.1ms preprocess, 59.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 58.9ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.38
# Clase --> person
# Confianza ---> 0.28
# Clase --> person
# Speed: 12.4ms preprocess, 58.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.2ms preprocess, 60.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 61.4ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.36
# Clase --> person
# Speed: 1.6ms preprocess, 61.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.3ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.9ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.4ms preprocess, 54.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 51.1ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.0ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.1ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.9ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 0.9ms preprocess, 60.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.4ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.8ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.3ms preprocess, 55.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.4ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.7ms preprocess, 60.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 53.3ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.4ms preprocess, 53.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.2ms preprocess, 54.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 52.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.8ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.8ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 0.9ms preprocess, 55.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 76.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.1ms preprocess, 76.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.2ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 13.5ms preprocess, 169.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.0ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 3.3ms preprocess, 103.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 79.3ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 7.3ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 86.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.2ms preprocess, 86.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 66.5ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 2.0ms preprocess, 66.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 68.8ms
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Speed: 1.1ms preprocess, 68.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 167.9ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.26
# Clase --> person
# Speed: 12.1ms preprocess, 167.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 55.1ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.32
# Clase --> person
# Speed: 1.0ms preprocess, 55.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 64.5ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.42
# Clase --> person
# Speed: 1.1ms preprocess, 64.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 58.3ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.26
# Clase --> person
# Speed: 1.1ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 57.2ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.34
# Clase --> person
# Speed: 1.7ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 66.7ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.49
# Clase --> person
# Speed: 1.0ms preprocess, 66.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 69.0ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.53
# Clase --> person
# Speed: 1.9ms preprocess, 69.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 62.1ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.5
# Clase --> person
# Speed: 1.2ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 55.3ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.53
# Clase --> person
# Speed: 1.3ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 56.7ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.36
# Clase --> person
# Speed: 1.3ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 56.7ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.51
# Clase --> person
# Speed: 1.1ms preprocess, 56.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 69.4ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.51
# Clase --> person
# Speed: 1.0ms preprocess, 69.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 91.7ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.48
# Clase --> person
# Speed: 1.1ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 72.3ms
# Confianza ---> 0.96
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.5
# Clase --> person
# Speed: 1.0ms preprocess, 72.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 67.7ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.39
# Clase --> person
# Speed: 1.0ms preprocess, 67.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 62.1ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.38
# Clase --> person
# Speed: 1.8ms preprocess, 62.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 76.6ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.43
# Clase --> person
# Speed: 1.2ms preprocess, 76.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 78.7ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.91
# Clase --> person
# Confianza ---> 0.34
# Clase --> person
# Speed: 1.2ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 64.9ms
# Confianza ---> 0.96
# Clase --> person
# Confianza ---> 0.91
# Clase --> person
# Confianza ---> 0.59
# Clase --> person
# Speed: 1.3ms preprocess, 64.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 58.6ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.91
# Clase --> person
# Confianza ---> 0.36
# Clase --> person
# Speed: 1.1ms preprocess, 58.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 52.5ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.91
# Clase --> person
# Confianza ---> 0.28
# Clase --> person
# Speed: 2.4ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 59.1ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Confianza ---> 0.28
# Clase --> person
# Speed: 1.7ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.9ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Speed: 15.8ms preprocess, 125.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.0ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Speed: 1.1ms preprocess, 53.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.4ms
# Confianza ---> 0.95
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Speed: 1.9ms preprocess, 55.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 53.6ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.92
# Clase --> person
# Speed: 1.1ms preprocess, 53.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 54.4ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.91
# Clase --> person
# Speed: 1.1ms preprocess, 54.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 55.9ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.83
# Clase --> person
# Speed: 1.1ms preprocess, 55.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 52.8ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.6
# Clase --> person
# Speed: 1.4ms preprocess, 52.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 80.2ms
# Confianza ---> 0.94
# Clase --> person
# Confianza ---> 0.53
# Clase --> person
# Speed: 2.4ms preprocess, 80.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 83.8ms
# Confianza ---> 0.93
# Clase --> person
# Confianza ---> 0.32
# Clase --> person
# Speed: 1.2ms preprocess, 83.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.4ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.2ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 63.2ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.1ms preprocess, 63.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 73.1ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.0ms preprocess, 73.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 74.1ms
# Confianza ---> 0.93
# Clase --> person
# Speed: 1.0ms preprocess, 74.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 54.7ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.1ms preprocess, 54.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 57.1ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 2.3ms preprocess, 57.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.2ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 1.4ms preprocess, 60.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.7ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.4ms preprocess, 59.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.2ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 8.0ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.3ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.1ms preprocess, 59.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 60.6ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 1.4ms preprocess, 60.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 59.9ms
# Confianza ---> 0.95
# Clase --> person
# Speed: 1.0ms preprocess, 59.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 56.3ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.0ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 55.4ms
# Confianza ---> 0.94
# Clase --> person
# Speed: 1.1ms preprocess, 55.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# Seguimiento. Requiere instalar lap con pip install lap

# %%
from collections import defaultdict
import numpy as np

# Carga del modelo, descarga en disco si no está presente en la carpeta
model = YOLO('yolo11n.pt') #Contenedores

# Etiqueta de las distintas clases
classNames = ["person", "bicycle", "car"]


# Captura desde la webcam
vid = cv2.VideoCapture(0)
track_history = defaultdict(lambda: [])
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Seguimiento, con persistencia entre fotogramas
        results = model.track(img, persist=True, classes = [0,1,2])

        if 0:
            if results is not None:
                print(results[0])
                boxes = results[0].boxes.xywh.cpu()
                track_ids = results[0].boxes.id.int().cpu().tolist()
                annotated_frame = results[0].plot()
                for box, track_id in zip(boxes, track_ids):
                    x, y, w, h = box
                    track = track_history[track_id]
                    track.append((float(x), float(y)))
                    if len(track) > 30:
                        track.pop(0)
                    points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                    cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)
                cv2.imshow("YOLO11 Tracking", annotated_frame)
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
        

        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

                #Etiqueta de seguimiento
                if box.id is not None:
                    track_id = str(int(box.id[0].tolist()))
                else:
                    track_id = ''
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confianza --->",confidence)

                # Clase
                cls = int(box.cls[0])
                print("Clase -->", classNames[cls])

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, track_id + ' ' + classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Intregración con seguimiento (tracking)
# !!!!!!!!!Nota: he tenido que bajar a la versión de python 3.9.5 e instalar lap con pip install lap

# %%
# Carga del modelo
model = YOLO('yolo11n.pt') #Contenedores
#model = YOLO('yolov11n-seg.pt') #Máscaras
#model = YOLO('yolo11n-pose.pt')  #Pose

#Para un vídeo 
filename = "TGC23_PdH_C0056cut.mp4"
results = model.track(source=filename, show=True)  # BoT-SORT tracker (por defecto)
#results = model.track(source=filename, show=True, tracker="bytetrack.yaml")  # ByteTrack tracker

cv2.destroyAllWindows()
